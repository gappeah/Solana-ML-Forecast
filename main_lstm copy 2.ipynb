# %% [markdown]
# ### Predicting Solana Price with Python and Machine Learning using Tensorflow and Keras and LSTM

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load the data
data = pd.read_csv('solana_2020-04-09_2024-10-26.csv')

# Sort data by the 'Start' date
data = data.sort_values('Start')

# Select relevant features
features = data[['Open', 'High', 'Low', 'Close', 'Volume']]

# Normalize the features using MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)

# Convert the scaled features into a DataFrame
scaled_data = pd.DataFrame(scaled_features, columns=features.columns)

# Display the first few rows of the scaled data
print(scaled_data.head())
# Out:
#        Open      High       Low     Close    Volume
# 0  0.000579  0.000714  0.000339  0.000649  0.000025
# 1  0.000674  0.002858  0.000431  0.001647  0.001460
# 2  0.001680  0.001893  0.001078  0.000989  0.002984
# 3  0.001055  0.001543  0.001058  0.001452  0.001555
# 4  0.001418  0.001236  0.001110  0.000987  0.001034

# %% [markdown]
# ### Create Sequences for LSTM

# %%
import numpy as np

def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length):
        sequence = data[i:i+sequence_length]
        target = data[i+sequence_length, 3]  # Assuming 'Close' is the target
        sequences.append((sequence, target))
    return sequences

sequence_length = 60  # Example sequence length
sequences = create_sequences(scaled_features, sequence_length)

# Split into training and testing sets
train_size = int(len(sequences) * 0.8)
train_sequences = sequences[:train_size]
test_sequences = sequences[train_size:]

# Prepare the data for the LSTM model
X_train = np.array([seq[0] for seq in train_sequences])
y_train = np.array([seq[1] for seq in train_sequences])
X_test = np.array([seq[0] for seq in test_sequences])
y_test = np.array([seq[1] for seq in test_sequences])

# %% [markdown]
# ### Build and Train the LSTM Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# c:\Users\Student\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0255 - val_loss: 3.8034e-04
# Epoch 2/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0037 - val_loss: 3.5772e-04
# Epoch 3/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0035 - val_loss: 1.9432e-04
# Epoch 4/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0025 - val_loss: 1.6895e-04
# Epoch 5/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0022 - val_loss: 1.8480e-04
# Epoch 6/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0028 - val_loss: 1.7072e-04
# Epoch 7/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0018 - val_loss: 1.7348e-04
# Epoch 8/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0021 - val_loss: 2.8678e-04
# Epoch 9/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0021 - val_loss: 1.1529e-04
# Epoch 10/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0017 - val_loss: 1.1169e-04
# Epoch 11/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0021 - val_loss: 1.2155e-04
# Epoch 12/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0017 - val_loss: 1.4227e-04
# Epoch 13/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0023 - val_loss: 1.0068e-04
# Epoch 14/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0022 - val_loss: 1.6728e-04
# Epoch 15/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0020 - val_loss: 8.5647e-05
# Epoch 16/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0021 - val_loss: 8.7024e-05
# Epoch 17/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0014 - val_loss: 8.0932e-05
# Epoch 18/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0014 - val_loss: 1.1737e-04
# Epoch 19/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0014 - val_loss: 8.1745e-05
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0017 - val_loss: 1.2169e-04

# %%
# Evaluate the model on the test set
loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Loss: {loss * 100}%')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0016
# Test Loss: 0.0015626822132617235
# Test Loss: 0.15626822132617235%

# %%
# Make predictions
predictions = model.predict(X_test)


# Reshape the predictions to match the scaler's expected input shape
predictions = predictions.reshape(-1, 1)

# Prepare a dummy array with the same shape as the scaled data (Open, High, Low, Close, Volume)
dummy_array = np.zeros((predictions.shape[0], scaled_features.shape[1]))

# Replace the 'Close' column in the dummy array with the predictions
dummy_array[:, 3] = predictions[:, 0]

# Perform inverse transformation
inverse_transformed_predictions = scaler.inverse_transform(dummy_array)

# Extract the predicted Close prices
predicted_prices = inverse_transformed_predictions[:, 3]

# Invert scaling for actual Close prices
actual_prices = y_test.reshape(-1, 1)
dummy_array = np.zeros((actual_prices.shape[0], scaled_features.shape[1]))
dummy_array[:, 3] = actual_prices[:, 0]
inverse_transformed_actual = scaler.inverse_transform(dummy_array)
actual_prices = inverse_transformed_actual[:, 3]

# Plot the results
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))
plt.plot(actual_prices, color='blue', label='Actual Solana Prices')
plt.plot(predicted_prices, color='red', label='Predicted Solana Prices')
plt.title('Solana Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step

# %% [markdown]
# ### Save the Model

# %%
model.save('solana_price_prediction_lstm.keras')

# %% [markdown]
# ## Load model

# %%
from tensorflow.keras.models import load_model

model = load_model('solana_price_prediction_lstm.keras')

# %% [markdown]
# ### Early Stopping: To stop training when the model stops improving.
# ### Learning Rate Scheduler: To adjust the learning rate during training.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

def create_model():
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    
    # Create a new optimizer instance
    optimizer = tf.keras.optimizers.Adam()
    
    # Compile the model with the new optimizer
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# %% [markdown]
# ### Train the model with early stopping:

# %%
# Create the model
model = create_model()

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# c:\Users\Student\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - loss: 0.0113 - val_loss: 2.6611e-04
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0037 - val_loss: 1.7392e-04
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0029 - val_loss: 2.7529e-04
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0033 - val_loss: 1.5386e-04
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0024 - val_loss: 3.3257e-04
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0028 - val_loss: 1.6477e-04
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0027 - val_loss: 1.1611e-04
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0021 - val_loss: 1.9753e-04
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.0023 - val_loss: 1.2755e-04
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0021 - val_loss: 2.9870e-04
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0020 - val_loss: 2.8332e-04
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0023 - val_loss: 1.2577e-04
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0021 - val_loss: 1.9912e-04
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0020 - val_loss: 1.2075e-04
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0015 - val_loss: 9.6013e-05
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0017 - val_loss: 9.5930e-05
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0015 - val_loss: 8.9952e-05
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0014 - val_loss: 9.1701e-05
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0019 - val_loss: 9.7919e-05
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0013 - val_loss: 8.6907e-05
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0016 - val_loss: 8.0864e-05
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0013 - val_loss: 7.8042e-05
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0014 - val_loss: 8.4518e-05
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0013 - val_loss: 8.1713e-05
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0011 - val_loss: 1.1227e-04
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0016 - val_loss: 1.2550e-04
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0013 - val_loss: 6.9011e-05
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0014 - val_loss: 8.6234e-05
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0013 - val_loss: 1.3716e-04
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0011 - val_loss: 1.8405e-04
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0014 - val_loss: 7.7960e-05
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0012 - val_loss: 8.6440e-05
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0015 - val_loss: 6.7407e-05
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0013 - val_loss: 6.9891e-05
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0013 - val_loss: 7.1491e-05
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0011 - val_loss: 1.3399e-04
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0014 - val_loss: 8.5722e-05
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0012 - val_loss: 8.9519e-05
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0013 - val_loss: 9.4651e-05
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0012 - val_loss: 7.4953e-05
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0011 - val_loss: 8.8011e-05
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0015 - val_loss: 1.3446e-04
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 6.2179e-05
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0012 - val_loss: 7.8679e-05
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0011 - val_loss: 1.3092e-04
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0012 - val_loss: 6.4081e-05
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - val_loss: 7.7053e-05
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0011 - val_loss: 8.4295e-05
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0011 - val_loss: 7.5559e-05
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0010 - val_loss: 6.0042e-05
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0012 - val_loss: 6.0411e-05
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0013 - val_loss: 6.5174e-05
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.5294e-04 - val_loss: 7.0982e-05
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.6868e-04 - val_loss: 6.4413e-05
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0010 - val_loss: 5.9858e-05
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0015 - val_loss: 1.2169e-04
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0011 - val_loss: 5.8822e-05
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0010 - val_loss: 1.0054e-04
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0010 - val_loss: 6.9900e-05
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.0015 - val_loss: 1.4784e-04
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.0010 - val_loss: 5.6959e-05
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0013 - val_loss: 5.9645e-05
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 9.0709e-04 - val_loss: 7.7087e-05
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0011 - val_loss: 7.4362e-05
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 8.3331e-04 - val_loss: 5.6194e-05
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0011 - val_loss: 5.6636e-05
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0010 - val_loss: 7.2011e-05
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0011 - val_loss: 5.9582e-05
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0012 - val_loss: 6.1809e-05
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0012 - val_loss: 9.3145e-05
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0012 - val_loss: 5.7612e-05
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.9412e-04 - val_loss: 7.2349e-05
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.9928e-04 - val_loss: 6.2164e-05
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 8.5498e-04 - val_loss: 7.2324e-05
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0010 - val_loss: 7.0475e-05

# %% [markdown]
# ### Hyperparameter Tuning

# %%
import kerastuner as kt

def model_builder(hp):
    model = Sequential()
    hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
    model.add(LSTM(units=hp_units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(units=hp_units, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    
    # Choose an optimal learning rate between 0.01 and 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='mean_squared_error')
    
    return model

tuner = kt.Hyperband(model_builder,
                    objective='val_loss',
                    max_epochs=20,
                    factor=3,
                    directory='my_dir',
                    project_name='intro_to_kt')

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

tuner.search(X_train, y_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the optimal hyperparameters and train it
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Trial 30 Complete [00h 02m 10s]
# val_loss: 9.150980622507632e-05
#
# Best val_loss So Far: 5.484760185936466e-05
# Total elapsed time: 00h 44m 34s
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 357ms/step - loss: 0.0188 - val_loss: 3.9534e-04
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 350ms/step - loss: 0.0012 - val_loss: 1.7306e-04
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 362ms/step - loss: 0.0012 - val_loss: 1.0540e-04
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - loss: 0.0013 - val_loss: 8.7104e-05
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 349ms/step - loss: 0.0012 - val_loss: 7.1259e-05
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 358ms/step - loss: 0.0011 - val_loss: 9.8473e-05
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - loss: 0.0013 - val_loss: 3.0954e-04
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - loss: 0.0016 - val_loss: 2.3389e-04
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - loss: 0.0011 - val_loss: 8.8831e-05
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 350ms/step - loss: 0.0015 - val_loss: 1.0429e-04
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 358ms/step - loss: 0.0012 - val_loss: 6.6328e-05
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - loss: 8.6647e-04 - val_loss: 1.0599e-04
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 433ms/step - loss: 0.0010 - val_loss: 6.5257e-05
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 392ms/step - loss: 9.3126e-04 - val_loss: 3.6354e-04
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - loss: 0.0011 - val_loss: 8.0695e-05
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 378ms/step - loss: 8.8985e-04 - val_loss: 7.6687e-05
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 392ms/step - loss: 0.0011 - val_loss: 1.6698e-04
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 373ms/step - loss: 0.0011 - val_loss: 6.5113e-05
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 379ms/step - loss: 8.2733e-04 - val_loss: 6.4662e-05
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 385ms/step - loss: 0.0010 - val_loss: 9.8944e-05
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - loss: 0.0011 - val_loss: 6.7203e-05
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - loss: 8.6755e-04 - val_loss: 5.5516e-05
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 375ms/step - loss: 8.8375e-04 - val_loss: 8.0227e-05
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 376ms/step - loss: 8.0222e-04 - val_loss: 6.0634e-05
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 379ms/step - loss: 8.1695e-04 - val_loss: 5.5509e-05
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 372ms/step - loss: 8.1740e-04 - val_loss: 2.3552e-04
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 376ms/step - loss: 8.0863e-04 - val_loss: 5.7191e-05
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - loss: 9.8751e-04 - val_loss: 1.0787e-04
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 658ms/step - loss: 0.0011 - val_loss: 5.2447e-05
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 607ms/step - loss: 6.9488e-04 - val_loss: 6.3149e-05
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 504ms/step - loss: 7.1890e-04 - val_loss: 2.1611e-04
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 367ms/step - loss: 7.9839e-04 - val_loss: 6.0691e-05
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 359ms/step - loss: 7.2854e-04 - val_loss: 1.0762e-04
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 391ms/step - loss: 6.9883e-04 - val_loss: 6.3218e-05
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - loss: 9.5160e-04 - val_loss: 8.5651e-05
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 360ms/step - loss: 9.8314e-04 - val_loss: 8.6547e-05
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 365ms/step - loss: 8.5987e-04 - val_loss: 6.1183e-05
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 360ms/step - loss: 6.8461e-04 - val_loss: 6.7174e-05
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 379ms/step - loss: 8.7466e-04 - val_loss: 6.1988e-05
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 409ms/step - loss: 7.0965e-04 - val_loss: 1.2304e-04
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 383ms/step - loss: 8.5656e-04 - val_loss: 5.2396e-05
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - loss: 7.5109e-04 - val_loss: 5.3807e-05
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 404ms/step - loss: 9.5580e-04 - val_loss: 5.1748e-05
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 391ms/step - loss: 9.2921e-04 - val_loss: 2.4691e-04
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 372ms/step - loss: 6.9009e-04 - val_loss: 9.7610e-05
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 389ms/step - loss: 6.4036e-04 - val_loss: 4.8740e-05
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - loss: 6.6565e-04 - val_loss: 4.7427e-05
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 378ms/step - loss: 7.0941e-04 - val_loss: 7.5318e-05
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 385ms/step - loss: 6.5757e-04 - val_loss: 5.7915e-05
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - loss: 0.0011 - val_loss: 6.8088e-05

# %% [markdown]
# # Model Architecture Visualization

# %%
import pydot
import graphviz
from tensorflow.keras.utils import plot_model

# Plot the model architecture
plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Training History Visualization

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(14, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Prediction Visualization

# %%
# Make predictions
predictions = model.predict(X_test)

# Reshape the predictions to match the scaler's expected input shape
predictions = predictions.reshape(-1, 1)

# Prepare a dummy array with the same shape as the scaled data (Open, High, Low, Close, Volume)
dummy_array = np.zeros((predictions.shape[0], scaled_features.shape[1]))

# Replace the 'Close' column in the dummy array with the predictions
dummy_array[:, 3] = predictions[:, 0]

# Perform inverse transformation
inverse_transformed_predictions = scaler.inverse_transform(dummy_array)

# Extract the predicted Close prices
predicted_prices = inverse_transformed_predictions[:, 3]

# Invert scaling for actual Close prices
actual_prices = y_test.reshape(-1, 1)
dummy_array = np.zeros((actual_prices.shape[0], scaled_features.shape[1]))
dummy_array[:, 3] = actual_prices[:, 0]
inverse_transformed_actual = scaler.inverse_transform(dummy_array)
actual_prices = inverse_transformed_actual[:, 3]

# Plot the results
plt.figure(figsize=(14, 5))
plt.plot(actual_prices, color='blue', label='Actual Solana Prices')
plt.plot(predicted_prices, color='red', label='Predicted Solana Prices')
plt.title('Solana Price Prediction After Hyperparameter Tuning')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import math

# Assuming X_test and y_test are already defined and you have a trained model

# Make predictions on the test set
y_pred = model.predict(X_test)

# If you used a MinMaxScaler or any other scaler on your y values, you'll need to inverse transform
# Assuming you used a MinMaxScaler called scaler_y to scale your y values:
# y_pred = scaler_y.inverse_transform(y_pred)
# y_test = scaler_y.inverse_transform(y_test.reshape(-1, 1))

# Flatten the predictions and actual values if they have more than 1 dimension
y_pred = y_pred.flatten()
y_test = y_test.flatten()

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
#print(f"Mean Squared Error: {mse}")
print(f"Mean Squared Error Percentage: {mse * 100:.2f}%")


# Calculate Root Mean Squared Error (RMSE)
rmse = math.sqrt(mean_squared_error(y_test, y_pred))
rmse_percentage = (rmse / max(y_test)) * 100
#print(f"Root Mean Squared Error: {rmse}")
print(f"Root Mean Squared Error (RMSE): {rmse_percentage:.2f}%")

# Calculate Mean Absolute Error (MAE)
mae = sum(abs(y_test - y_pred)) / len(y_test)
mae_percentage = (mae / max(y_test)) * 100
#print(f"Mean Absolute Error: {mae}")
print(f"Mean Absolute Error (MAE): {mae_percentage:.2f}%")

# Calculate R-squared (R²)
r2 = r2_score(y_test, y_pred)
# print(f"R-squared: {r2}")
print(f"R-squared Percentage: {r2 * 100:.2f}%")

# If you want an accuracy score (though typically not used in regression)
# Define an accuracy metric, e.g., percentage of predictions within a certain threshold of actual value
accuracy = np.mean(np.abs(y_test - y_pred) <= 0.1 * y_test) * 100
print(f"Accuracy: {accuracy}%")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# Mean Squared Error Percentage: 0.09%
# Root Mean Squared Error (RMSE): 3.77%
# Mean Absolute Error (MAE): 2.95%
# R-squared Percentage: 93.29%
# Accuracy: 93.45794392523365%
